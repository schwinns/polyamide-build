# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
a1 = np.array([0.9434443839533885,16.031129307099302,-30.803662824698975])
a2 = np.array([0.3251980206328903,15.42824542129001,-31.211422153092826])
a3 = np.array([0.3260860214447196,15.430554813599006,-31.22330719138064])

# %%
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
ax.scatter(xs=a1[0],ys=a1[1],zs=a1[2], c='red')
ax.scatter(xs=a2[0],ys=a2[1],zs=a2[2], c='white')
ax.scatter(xs=a3[0],ys=a3[1],zs=a3[2], c='white')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-e9624677a1c9> in <module>
#       2 ax = fig.add_subplot(projection='3d')
#       3 ax.scatter(xs=a1[0],ys=a1[1],zs=a1[2])
# ----> 4 ax.scatter(a2)
#       5 ax.scatter(a3)
#
# TypeError: scatter() missing 1 required positional argument: 'ys'
